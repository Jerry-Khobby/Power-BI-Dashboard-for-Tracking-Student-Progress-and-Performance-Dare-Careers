# %%
import pandas as pd 
import numpy as np
# Out:
# Running cells with 'Python 3.11.14' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/JeremiahAnkuCoblah/.local/bin/python3.11.exe -m pip install ipykernel -U --user --force-reinstall'
